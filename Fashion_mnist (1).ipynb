# %% [markdown]
# ### Load Tensorflow and Matplot

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

# %%
(train_X, train_Y), (test_X, test_Y) = fashion_mnist.load_data()

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
              'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot' ]

# %% [markdown]
# ### Explore the data

# %%
train_X.shape
# Out:
# (60000, 28, 28)

# %%
len(train_Y)
# Out:
# 60000

# %%
train_Y
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_X.shape
# Out:
# (10000, 28, 28)

# %%
len(test_Y)
# Out:
# 10000

# %% [markdown]
# ### Preprocess the data

# %%
plt.figure()
plt.imshow(train_X[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
train_X = train_X/255.0
test_X = test_X/255.0

# %%
plt.figure(figsize = (10,10))
for i in range(25):
    plt.subplot(5,5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_X[i], cmap = plt.cm.binary)
    plt.xlabel(class_names[train_Y[i]])
plt.show()

# %% [markdown]
# ### Build the Model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Reshape((784,), input_shape = (28,28,)))
model.add(tf.keras.layers.Dense(200, activation = 'relu'))
model.add(tf.keras.layers.Dense(10))

# %%
model.compile(optimizer = 'adam',
              loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True ),
              metrics = ['accuracy'])

# %%
model.fit(train_X, train_Y,
          validation_data = (test_X, test_Y),
          epochs = 24)
# Out:
# Epoch 1/24
# 1875/1875 [==============================] - 9s 2ms/step - loss: 0.4952 - accuracy: 0.8253 - val_loss: 0.4572 - val_accuracy: 0.8328
# Epoch 2/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3669 - accuracy: 0.8680 - val_loss: 0.3827 - val_accuracy: 0.8640
# Epoch 3/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3301 - accuracy: 0.8791 - val_loss: 0.3635 - val_accuracy: 0.8693
# Epoch 4/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3061 - accuracy: 0.8862 - val_loss: 0.3461 - val_accuracy: 0.8734
# Epoch 5/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2864 - accuracy: 0.8940 - val_loss: 0.3496 - val_accuracy: 0.8716
# Epoch 6/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2754 - accuracy: 0.8981 - val_loss: 0.3312 - val_accuracy: 0.8817
# Epoch 7/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2604 - accuracy: 0.9032 - val_loss: 0.3678 - val_accuracy: 0.8696
# Epoch 8/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2498 - accuracy: 0.9078 - val_loss: 0.3438 - val_accuracy: 0.8760
# Epoch 9/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2403 - accuracy: 0.9110 - val_loss: 0.3255 - val_accuracy: 0.8863
# Epoch 10/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2306 - accuracy: 0.9137 - val_loss: 0.3290 - val_accuracy: 0.8856
# Epoch 11/24
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2234 - accuracy: 0.9176 - val_loss: 0.3339 - val_accuracy: 0.8820
# Epoch 12/24
# 1838/1875 [============================>.] - ETA: 0s - loss: 0.2156 - accuracy: 0.9199
